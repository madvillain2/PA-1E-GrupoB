# %% [markdown]
# <a href="https://colab.research.google.com/github/madvillain2/PA-1E-GrupoB/blob/main/PA_22_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pedir o usuário para digitar um número e o programa imprimir os números pares

i = int(input("Digite um número: "))
for i in range(0, i):
  if i % 2 == 0:
    print(i)

# %%
for i in range(0, 100, 3):
    print(i)
