# %% [markdown]
# <a href="https://colab.research.google.com/github/madvillain2/PA-1E-GrupoB/blob/main/C%C3%B3pia_de_projetosPA_11_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calcular área de retângulo

# Entrada

comprimento = float (input("Digite o comprimento do retângulo:"))
altura = float (input("Digite a altura do retângulo:"))

# Processamento

area = comprimento * altura

# Saída

print(f"A área do retângulo é igual à: {area}")
# Out:
# Digite o comprimento do retângulo:4379285
# Digite a altura do retângulo:2352545
# A área do retângulo é igual à: 10302465030325.0

# %%
# Escrever o dobro de um número

# Entrada

numero = int (input("Digite um número:"))

# Processamento

dobro = numero * 2

# Saída

print (f"O dobro de {numero} é igual à: {dobro}")
# Out:
# Digite um número:0.000000000000000065438334923279743256
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_185/1532275156.py in <cell line: 0>()
#       3 # Entrada
#       4
# ----> 5 numero = int (input("Digite um número:"))
#       6
#       7 # Processamento
#
# ValueError: invalid literal for int() with base 10: '0.000000000000000065438334923279743256'

# %%
# EScrever um cadastro de usuário
# Entrada : nome e idade
# Processamento : armazenar os dados do usuário
# Saída : mostra uma mensagem de boas vindas e o nome e a idade do usuário

# Entrada

nome = str(input("Digite seu nome:"))
idade = int(input("Digite sua idade:"))

# Processamento

# Saída

print (f"Olá, {nome}. Seja muito bem vindo!")
print(f"Você tem {idade} anos.")
# Out:
# Digite seu nome:9
# Digite sua idade:6[
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_185/3133898921.py in <cell line: 0>()
#       7
#       8 nome = str(input("Digite seu nome:"))
# ----> 9 idade = int(input("Digite sua idade:"))
#      10
#      11 # Processamento
#
# ValueError: invalid literal for int() with base 10: '6['

# %% [markdown]
# Escrever um algoritmo que calcula o triplo de um número

# %%
# Escrever o triplo de um número

# Entrada

numero = float(input("Digite um número:"))



triplo = numero * 3

# Saída

print (f"O triplo de {numero} é igual à: {triplo}")
# Out:
# O triplo de 9.0 é igual à: 27.0

# %% [markdown]
# Escrever um programa que receba o nome do usuário e mostre uma mensagem com o ano em que a pessoa nasceu

# %%
# Escrever um programa que receba o nome do usuário e mostre uma mensagem com o ano em que a pessoa nasceu

# Entrada

nome = str(input("Digite seu nome:"))
ano_de_nascimento = int(input("Digite o ano em que você nasceu:"))

# Processamento

idade = 2026 - ano_de_nascimento

# Saída

print (f"Olá, {nome}. Você tem {idade} anos.")
# Out:
# Digite seu nome:fripe
# Digite o ano em que você nasceu:1999
# Olá, fripe. Você tem 27 anos.

# %%
# Escrever um proograma que faz a conversão de temperatura

# Entrada : temperatura em Celsius

temperatura = float(input("Digite a temperatura em Celsius:"))

# Processamento : Converter para Fahrenheit

fahrenheit = (temperatura * 9/5) + 32

# Saída : resultado

print (f"Resultado: {fahrenheit} ")

# Formula : F = (C * 9/5) + 32
# Out:
# Digite a temperatura em Celsius:9
# Resultado: 48.2
