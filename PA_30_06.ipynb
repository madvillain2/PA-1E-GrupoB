# %% [markdown]
# <a href="https://colab.research.google.com/github/madvillain2/PA-1E-GrupoB/blob/main/PA_30_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cofre digital

# Um cofre possui um código composto por 5 números inteiros.

# Desenvolva um programa que:

# Leia os 5 números utilizando um laço de repetição.

# Ao final informar:

# 1 - Quantos números são pares.
# 2 - Quantos números são ímpares.
# 3 - O maior número.
# 4 - A soma de todos os números.
# 5 - A média dos números
# 6 - O menor número
# 7 - Quantos números são maiores que a média

numeros = 0
tempo = 0

while tempo != 5:
  try:
      numeros = int(input("Digite um número."))
      tempo += 1
      numeros2 = int(input("Digite um número."))
      tempo += 1
      numeros3 = int(input("Digite um número."))
      tempo += 1
      numeros4 = int(input("Digite um número."))
      tempo += 1
      numeros5 = int(input("Digite um número."))
      tempo += 1

      if numeros % 2 == 0:
        print (f"{numeros} é par")

      if numeros % 2 != 0:
        print (f"{numeros} é ímpar")

      if numeros > numeros2 and numeros > numeros3 and numeros > numeros4 and numeros > numeros5:
          print(f"{numeros} é o maior número")

      if numeros < numeros2 and numeros < numeros3 and numeros < numeros4 and numeros < numeros5:
          print(f"{numeros} é o menor número")



      if numeros2 % 2 == 0:
        print (f"{numeros2} é par")

      if numeros2 % 2 != 0:
        print (f"{numeros2} é ímpar")

      if numeros2 > numeros and numeros2 > numeros3 and numeros2 > numeros4 and numeros2 > numeros5:
          print(f"{numeros2} é o maior número")

      if numeros2 < numeros and numeros2 < numeros3 and numeros2 < numeros4 and numeros2 < numeros5:
          print(f"{numeros2} é o menor número")



      if numeros3 % 2 == 0:
        print (f"{numeros3} é par")

      if numeros3 % 2 != 0:
        print (f"{numeros3} é ímpar")

      if numeros3 > numeros and numeros3 > numeros2 and numeros3 > numeros4 and numeros3 > numeros5:
        print(f"{numeros3} é o maior número")
      if numeros3 < numeros and numeros3 < numeros2 and numeros3 < numeros4 and numeros3 < numeros5:
          print(f"{numeros3} é o menor número")



      if numeros4 % 2 == 0:
        print (f"{numeros4} é par")

      if numeros4 % 2 != 0:
        print (f"{numeros4} é ímpar")

      if numeros4 > numeros and numeros4 > numeros2 and numeros4 > numeros3 and numeros4 > numeros5:
          print(f"{numeros4} é o maior número")

      if numeros4 < numeros and numeros4 < numeros2 and numeros4 < numeros3 and numeros4 < numeros5:
          print(f"{numeros4} é o menor número")



      if numeros5 % 2 == 0:
        print (f"{numeros5} é par")

      if numeros5 % 2 != 0:
        print (f"{numeros5} é ímpar")

      if numeros5 > numeros and numeros5 > numeros2 and numeros5 > numeros3 and numeros5 > numeros4:
          print(f"{numeros5} é o maior número")

      if numeros5 < numeros and numeros5 < numeros2 and numeros5 < numeros3 and numeros5 < numeros4:
          print(f"{numeros5} é o menor número")


      media = (numeros + numeros2 + numeros3 + numeros4 + numeros5) / 5

      if numeros > media:
        print(f"{numeros} é maior que a média")

      if numeros2 > media:
        print(f"{numeros2} é maior que a média")

      if numeros3 > media:
        print(f"{numeros3} é maior que a média")

      if numeros4 > media:
        print(f"{numeros4} é maior que a média")

      if numeros5 > media:
        print(f"{numeros5} é maior que a média")


      print(f"A soma de todos os números é de {numeros + numeros2 + numeros3 + numeros4 + numeros5}")
      print(f"A média de todos os números é de {media}")
  except:
    if numeros < 0:
      print(f"Não são permitidos os números negativos.")

    if numeros2 < 0:
      print(f"Não são permitidos os números negativos.")

    if numeros3 < 0:
      print(f"Não são permitidos os números negativos.")

    if numeros4 < 0:
      print(f"Não são permitidos os números negativos.")

    if numeros5 < 0:
      print(f"Não são permitidos os números negativos.")
# Out:
# Digite um número.-4

# %%
try:
  numero = input("Digite um número: ")
  if numero < 0:
    print("Não são permitidos os números negativos.")

  numero_invertido = numero[::-1]


  print("Número invertido:")
  print(numero_invertido)
except:
  if numero < 0:
    print("Não são permitidos os números negativos.")
