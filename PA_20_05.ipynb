# %% [markdown]
# <a href="https://colab.research.google.com/github/madvillain2/PA-1E-GrupoB/blob/main/PA_20_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (5):
  print (i)

# %%
contador = 0

while contador < 5:
  print(contador)
  contador += 1

# %%
senha = ""

while senha != 1234:
  senha = int(input("Digite sua senha "))
  print (f"Acesso permitido.")

# %%
# Escrever um programa que faz uma contagem regressiva de 10 até zero e imprime uma mensagem de "acabou" no final.

contador = 10

while contador >= 0:
  print(contador)
  contador -= 1

print (f"A contagem acabou.")

# %%
# Escrever um programa que recebe as notas do aluno, calcula a média e imprime "aprovado", "recuperação", "reprovado". Utilizar while, nota >= 7 "aprovado", >= "recuperação", 5 < "reprovado".

notas = 0
bimestre = 1
soma = 0

try:

  while bimestre <= 4:
      notas = float(input("Digite suas notas: "))
      bimestre += 1

      soma = soma + notas

      notafinal = soma / 4

  if notafinal >= 7:
      print(f"Sua nota final é de {notafinal}. Você foi aprovado.")

  elif notafinal >= 5:
      print(f"Sua nota final é de {notafinal}. Você está de recuperação.")

  else:
      10
      print(f"Sua nota final é de {notafinal}. Você foi reprovado.")

except:
  print("Digite apenas números.")
# Out:
# Digite suas notas: 7
# Digite suas notas: 8
# Digite suas notas: 9
# Digite suas notas: 7
# Sua nota final é de 7.75. Você foi aprovado.

# %%
saldo = 1000.00
opcao = 0

while opcao != 4:
    print("1 - Ver saldo")
    print("2 - Depositar dinheiro")
    print("3 - Sacar dinheiro")
    print("4 - Sair")

    opcao = int(input("Digite a opção desejada: "))

    if opcao == 1:
      print(f"Seu saldo é igual a {saldo}")

    if opcao == 2:
      valor_deposito = float(input("Digite o valor do seu deposito: "))
      saldo = saldo + valor_deposito
      print(f"")
      print(f"")
      print(f"Você depositou R${valor_deposito}")
      print(f"Seu saldo agora é de: R${saldo}")
      print(f"")
      print(f"")

    if opcao == 3:
      valor_sacar = float(input("Digite o valor que quer sacar: "))
      saldo = saldo - valor_sacar
      print(f"")
      print(f"")
      print(f"Você sacou R${valor_sacar}")
      print(f"Seu saldo agora é de R${saldo}")
      print(f"")
      print(f"")

    if opcao == 4:
      print(f"")
      print(f"OBRIGADO POR USAR ESTE CAIXA ELETRÔNICO!")
# Out:
# 1 - Ver saldo
# 2 - Depositar dinheiro
# 3 - Sacar dinheiro
# 4 - Sair

# %%
# Calculadora simples

opcao = 0

while opcao != 4:
  print("Opção 1 Seja bem vindo")
  print("Opção 2 somar")
  print("Opção 3 subtrair")
  print("Opção 4 sair")

  opcao = int(input("Digite a opção desejada: "))

  if opcao == 1:
    print ("Seja bem vindo.")

  elif opcao == 2:
    a = int (input("Digite o primeiro valor: "))
    b = int (input("Digite o segundo valor: "))
    print (f"{a} + {b} = {a+b}")


  elif opcao == 3:
    a = int (input("Digite o primeiro valor: "))
    b = int (input("Digite o segundo valor: "))
    print (f"{a} - {b} = {a-b}")
# Out:
# Opção 1 Seja bem vindo
# Opção 2 somar
# Opção 3 subtrair
# Opção 4 sair
# Digite a opção desejada: 1
# Seja bem vindo.
# Opção 1 Seja bem vindo
# Opção 2 somar
# Opção 3 subtrair
# Opção 4 sair
# Digite a opção desejada: 3
# Digite o primeiro valor: 4
# Digite o segundo valor: 10
# 4 - 10 = -6
# Opção 1 Seja bem vindo
# Opção 2 somar
# Opção 3 subtrair
# Opção 4 sair
# Digite a opção desejada: 4
