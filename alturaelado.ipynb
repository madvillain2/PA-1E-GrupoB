# %% [markdown]
# <a href="https://colab.research.google.com/github/madvillain2/PA-1E-GrupoB/blob/main/alturaelado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula de Programação e Algoritmos
# - Calculo de área
#
# #Entrada
#
# - ler lado1
#
# - ler lado2
#
# #Processamento
# area = lado1 * lado2
#
# #Saída
#
# imprimir area

# %%
#Entrada

lado1 = 4.5
lado2 = 5
altura = 2.5

nome = "Luiz Miguel"


#Processamento

area = lado1 * lado2
metroscubicos = area * altura


#Saída

print(f"Total da área:{area}")
print(f"Metros cúbicos:{metroscubicos}")
print(f"Nome:{nome}")


#Tipos Númericos
idade = 25
altura = 1.75
numero_complexo = 2 + 3j

#Tipo Texto
nome = "Luiz" # str

#Tipo Booleano
esta_chuvendo = False # bool
# Out:
# Total da área:22.5
# Metros cúbicos:56.25
# Nome:Luiz Miguel

# %% [markdown]
# ### Repetindo um número como parte de uma string ou lista
